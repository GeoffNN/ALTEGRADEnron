# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import pickle
import time


import src.tools as tools
import src.recencytools as recency
import src.randombaseline as randombaseline
import src.postprocess as postprocess
import src.preprocess as preprocess
import src.scoring as scoring

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
path_to_data = 'data/'

training = pd.read_csv(path_to_data + 'training_set.csv', sep=',', header=0)

training_info = pd.read_csv(
    path_to_data + 'training_info.csv', sep=',', parse_dates=True, header=0)

test = pd.read_csv(path_to_data + 'test_set.csv', sep=',', header=0)

test_info = pd.read_csv(path_to_data + 'test_info.csv',
                        sep=',', parse_dates=True, header=0)

path_to_results = 'results/'

# %%
training
# Out:
#                                 sender  \
# 0              karen.buckley@enron.com
# 1                amr.ibrahim@enron.com
# 2                andrea.ring@enron.com
# 3                  sylvia.hu@enron.com
# 4            phillip.platter@enron.com
# 5            richard.shapiro@enron.com
# 6               megan.parker@enron.com
# 7              david.forster@enron.com
# 8                 mike.maggi@enron.com
# 9             justin.rostant@enron.com
# 10          marcus.nettelton@enron.com
# 11         kathleen.carnahan@enron.com
# 12           grace.rodriguez@enron.com
# 13          hunter.s.shively@enron.com
# 14          sandra.f.brawner@enron.com
# 15                l..nicolay@enron.com
# 16                mark.whitt@enron.com
# 17             james.derrick@enron.com
# 18       darrell.schoolcraft@enron.com
# 19                 l..denton@enron.com
# 20            cheryl.johnson@enron.com
# 21                scott.neal@enron.com
# 22             chris.germany@enron.com
# ...

# %%
val_info
# Out:
#           mid                 date  \
# 22323  190751  2001-10-25 10:44:21
# 4873    41554  2001-10-25 10:45:52
# 1749    28352  2001-10-25 10:57:50
# 38763  365329  2001-10-25 11:02:15
# 8424    79942  2001-10-25 11:05:11
# 43602  404466  2001-10-25 11:06:34
# 29253  269206  2001-10-25 11:06:34
# 23811  205129  2001-10-25 11:08:54
# 5936    49809  2001-10-25 11:08:54
# 5935    49808  2001-10-25 11:18:21
# 24257  208154  2001-10-25 11:18:56
# 5934    49807  2001-10-25 11:18:56
# 4452    40454  2001-10-25 11:20:34
# 7740    72009  2001-10-25 11:20:55
# 43250  391894  2001-10-25 11:21:25
# 4453    40455  2001-10-25 11:21:25
# 22344  190845  2001-10-25 11:22:21
# 15913  156331  2001-10-25 11:22:21
# 7676    71391  2001-10-25 11:22:21
# 23810  205127  2001-10-25 11:22:21
# 24127  207575  2001-10-25 11:22:21
# 10310   94522  2001-10-25 11:22:21
# 32030  286889  2001-10-25 11:22:21
# 10490  100765  2001-10-25 11:22:21
# 6425    50612  2001-10-25 11:22:21
# ...

# %%
test_info
# Out:
#          mid                 date  \
# 1739  284098  2001-11-02 05:25:29
# 1598  272008  2001-11-02 05:34:55
# 343    49273  2001-11-02 05:57:55
# 494    71901  2001-11-02 06:10:47
# 562    82354  2001-11-02 06:17:44
# 561    82353  2001-11-02 06:26:44
# 1293  207543  2001-11-02 06:29:14
# 698   101120  2001-11-02 06:40:07
# 360    50955  2001-11-02 06:48:19
# 354    50917  2001-11-02 06:48:56
# 1129  187145  2001-11-02 06:55:20
# 389    53513  2001-11-02 06:56:28
# 584    85341  2001-11-02 07:05:25
# 1702  279648  2001-11-02 07:31:03
# 1245  204747  2001-11-02 07:47:19
# 2342  398254  2001-11-02 07:57:50
# 969   159593  2001-11-02 08:07:01
# 1701  279647  2001-11-02 08:13:31
# 388    53510  2001-11-02 08:17:37
# 361    51081  2001-11-02 08:17:37
# 1278  207434  2001-11-02 08:17:37
# 1700  279646  2001-11-02 08:19:14
# 1905  298389  2001-11-02 08:39:13
# 697   101114  2001-11-02 08:47:02
# 1065  176682  2001-11-02 08:49:18
# 2006  326107  2001-11-02 08:53:18
# ...

# %%
train_info, train_email_ids_per_sender, val_info, val_email_ids_per_sender = scoring.get_train_val(training,
                                                                                                   training_info,
                                                                                                   train_frac=0.95)
# Out:
# Processing training !
#
# Processing val !

# %%
all_recipients_ = preprocess.get_all_recipients_from_df(train_info)

# %%
random_predictions =  randombaseline.get_random_predictions(val_info, all_recipients_, k=10)

# %%
random_predictions
# Out:
# {81921: ['d..cisneros@enron.com',
#   'swatch@babybedding.com',
#   'aarati.sivasubramanian@enron.com',
#   'michael.springer@westgroup.com',
#   'dbehrman@ftenergy.com',
#   'peter.styles@enron.com',
#   'jessica.burry@enron.com',
#   'beth.jenkins@enron.com',
#   'phil.demoes@enron.com',
#   'mwardell@roseville.ca.us'],
#  79190: ['andy@episa.ch',
#   'caroline.schaeffer@enron.com',
#   'kathy.axford@enron.com',
#   'cynthia.franklin@enron.com',
#   'jkeil@mnpower.com',
#   'iz.wong@enron.com',
#   'rex@arn.net',
#   'raphael.brun@enron.com',
#   'jenp@tfts.tozzini.com.br',
#   'cynthia.clark@enron.com'],
#  85338: ['paul.lebeau@enron.com',
#   'wconwell@rr.com',
#   'fraisy.george@enron.com',
#   'sean.crandall@enron.com',
#   'claudia.bernal@enron.com',
#   'suzanne.brown@enron.com',
#   'jez.peters@enron.com',
#   'kal.shah@enron.com',
#   'webmaster@knxv.com',
#   'cwhite@duke-energy.com'],
#  326320: ['rebekah.rushing@enron.com',
#   'snguyen@totalsafetyinc.com',
# ...

# %%
current_score = scoring.compute_prediction_mad(random_predictions, val_info)
print(current_score)
# Out:
# 0.000142500527645

# %% [raw]
# print(current_score)
