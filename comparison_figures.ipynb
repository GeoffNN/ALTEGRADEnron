# %%
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
models = ['bayesian', 'tfidf\nknn',
          'tfidf\ncentroids', 'twidf\nglobal', 'twidf\n sender',
          'recency', 'recency\n+ bayes\n+tfdif\nknn', 'recency\n+bayes\n+rand forest\n+tfidf\ncentroids']
scores = [0.35113, 0.22123,
          0.24196, 0.20485, 0.30288,
         0.39679, 0.41863, 0.41043]
colors = ['blue', 'blue', 'blue',
         'blue', 'blue', 'blue',
         'purple', 'purple']
lefts = [2* i for i in range(len(models))]

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
rects1 = ax.bar(left=lefts, height=scores, color=colors, width=1, align='center')
ax.set_xticks(lefts)
ax.set_xticklabels(models)
ax.set_title('Model scores on the private leaderboard')
fig.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:372: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
